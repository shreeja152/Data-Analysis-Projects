# %%
scores = [ 45, 67, 98, 74, 62]

for scores in scores : 
    if scores >= 75:
        print (scores, "Distinction")
    elif scores >= 50: 
        print (scores, "Pass")
    else: 
        print (scores, "Fail")
# Out:
# 45 Fail
# 67 Pass
# 98 Distinction
# 74 Pass
# 62 Pass
