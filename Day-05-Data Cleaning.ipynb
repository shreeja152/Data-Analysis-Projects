# %%
data = [100, 200, None, 400, "", 600]

clean_data = []

for value in data : 
    if value not in [None, ""] : 
        clean_data.append(value)

print ("Clean Data : ", clean_data)
print ("Tota Value : ", sum(clean_data))
# Out:
# Clean Data :  [100, 200, 400, 600]
# Tota Value :  1300
