# %%
expences = [350, 590, 945, 938, 221, 20]

print ("Highest : ", max(expences))
print ("Cheapest : ", min(expences))
print ("Total exp : ", sum(expences))
print ("Average exp : ", sum(expences)/len(expences))
# Out:
# Highest :  945
# Cheapest :  20
# Total exp :  3064
# Average exp :  510.6666666666667
