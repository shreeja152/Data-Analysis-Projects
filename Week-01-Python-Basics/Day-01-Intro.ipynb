# %%
print("Hello, Data Analyst!")

name = "Alex"
age = 25
weight = 55

print("Name:", name)
print("Age:", age)
print("Weight:", weight)
# Out:
# Hello, Data Analyst!
# Name: Alex
# Age: 25
# Weight: 55
