# %% [markdown]
# ## Week 1 Reflection
#
# This week focused on building a strong foundation in Python for data analysis.
#
# Key learnings:
# - How to structure data using lists
# - Writing conditional logic to classify data
# - Cleaning datasets by handling missing values
# - Using Python to calculate summaries such as total, average, minimum, and maximum
#
# These exercises helped in understanding how Python can be applied to real-world data analysis tasks.
